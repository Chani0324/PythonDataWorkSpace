# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]

plt.plot(x, y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x00000177D33DBCD0>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용시 '-' 깨지는 현상 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['cmr10',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmb10',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'STIXSizeFiveSym',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'cmmi10',
#  'cmtt10',
#  'STIXSizeFourSym',
#  'cmex10',
#  'DejaVu Sans Display',
#  'cmss10',
#  'cmsy10',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'Rockwell',
#  'Tahoma',
#  'Elephant',
#  'Courier New',
#  'Cambria',
#  'Rage Italic',
#  'Kristen ITC',
#  'Courier New',
#  'Perpetua',
#  'OCR A Extended',
#  'Eras Medium ITC',
#  'Impact',
#  'Gadugi',
#  'MS Reference Specialty',
#  'Tw Cen MT',
#  'Microsoft Tai Le',
#  'Leelawadee UI',
#  'Rockwell Condensed',
#  'HYShortSamul-Medium',
#  'Gloucester MT Extra Condensed',
#  'Bodoni MT',
#  'Engravers MT',
#  'MJemokBatang',
#  'Tw Cen MT Condensed',
#  'Algerian',
#  'Tw Cen MT',
#  'High Tower Text',
#  'Forte',
#  'Lucida Bright',
#  'HCR Dotum',
#  'Bodoni MT',
#  'High Tower Text',
#  'Garamond',
#  'Gill Sans MT',
#  '?l?r ?S?V?b?N',
#  'Eras Demi ITC',
#  'Rockwell Condensed',
#  'Segoe UI',
#  'HCR Batang',
#  'Century Schoolbook',
#  'Franklin Gothic Heavy',
#  'Century Schoolbook',
#  'Bahnschrift',
#  'Franklin Gothic Demi',
#  'Lucida Sans',
#  'Edwardian Script ITC',
#  'Corbel',
#  'Lucida Fax',
#  'Microsoft JhengHei',
#  'Georgia',
#  'Century Gothic',
#  'GyeonggiTitle',
#  'Candara',
#  'Magic R',
#  'Rockwell',
#  'Colonna MT',
#  'Monotype Corsiva',
#  'Verdana',
#  'MGungJeong',
#  'Californian FB',
#  'HYGraphic-Medium',
#  'MSugiHeulim',
#  'Harlow Solid Italic',
#  'Lucida Bright',
#  'Lucida Calligraphy',
#  'Gill Sans MT',
#  'Consolas',
#  'Bell MT',
#  'Kunstler Script',
#  'Garamond',
#  'Berlin Sans FB Demi',
#  'MJemokGothic',
#  'Segoe MDL2 Assets',
#  'Felix Titling',
#  'Courier New',
#  'Cambria',
#  'Segoe UI Historic',
#  'Modern No. 20',
#  'Leelawadee UI',
#  'Arial',
#  'Segoe UI',
#  'Snap ITC',
#  'Leelawadee UI',
#  'Britannic Bold',
#  'UD Digi Kyokasho N-R',
#  'French Script MT',
#  'Microsoft Himalaya',
#  'Informal Roman',
#  'MHunmin',
#  'GyeonggiTitle',
#  '?? ??? ?B',
#  'Times New Roman',
#  'Parchment',
#  'Eras Bold ITC',
#  'Microsoft YaHei',
#  'Webdings',
#  'Microsoft Tai Le',
#  'Freestyle Script',
#  'Calibri',
#  'Trebuchet MS',
#  'Microsoft JhengHei',
#  'Copperplate Gothic Light',
#  'Goudy Old Style',
#  'Vladimir Script',
#  'TCometS',
#  'Segoe UI',
#  'GyeonggiTitle',
#  'Consolas',
#  'Rockwell Extra Bold',
#  'Corbel',
#  'Georgia',
#  'HYPost-Medium',
#  'Ami R',
#  'Bookman Old Style',
#  'Tw Cen MT',
#  'Yu Gothic',
#  'Matura MT Script Capitals',
#  'Calibri',
#  'Microsoft New Tai Lue',
#  'Goudy Old Style',
#  'Gill Sans MT Ext Condensed Bold',
#  'Myanmar Text',
#  'Segoe UI Emoji',
#  'MT Extra',
#  'Castellar',
#  'High Tower Text',
#  'Consolas',
#  'Tw Cen MT Condensed Extra Bold',
#  'Microsoft YaHei',
#  'TComet',
#  'MDotum',
#  'Yu Mincho',
#  'Lucida Sans',
#  'Trebuchet MS',
#  'Franklin Gothic Medium',
#  'Comic Sans MS',
#  'MingLiU-ExtB',
#  'Segoe UI',
#  'Franklin Gothic Medium',
#  'TwoComet',
#  'Lucida Calligraphy',
#  'Rockwell',
#  'Century Schoolbook',
#  'Goudy Old Style',
#  'HYHeadLine-Medium',
#  '?l?r ?S?V?b?N',
#  'Showcard Gothic',
#  'Microsoft JhengHei',
#  'Franklin Gothic Medium Cond',
#  'Javanese Text',
#  'Arial',
#  'Microsoft Yi Baiti',
#  'Consolas',
#  'Nirmala UI',
#  'Showcard Gothic',
#  'Book Antiqua',
#  'Leelawadee UI',
#  'Segoe UI',
#  'Pyunji R',
#  'MS Outlook',
#  'Cambria',
#  'Nirmala UI',
#  'HYGraphic-Medium',
#  'Gulim',
#  'Myanmar Text',
#  'Lucida Sans',
#  'Webdings',
#  'Eras Light ITC',
#  'Pyunji R',
#  'Ebrima',
#  'Yu Gothic',
#  'Gill Sans MT',
#  'HYMyeongJo-Extra',
#  'Georgia',
#  'Bodoni MT',
#  'Perpetua',
#  'Constantia',
#  'Wide Latin',
#  'SimSun-ExtB',
#  'Lucida Bright',
#  'Palatino Linotype',
#  'Microsoft Tai Le',
#  'Bookman Old Style',
#  'Bernard MT Condensed',
#  'Gigi',
#  'Microsoft JhengHei',
#  'Jokerman',
#  'Bell MT',
#  'Corbel',
#  'Segoe UI Symbol',
#  'Century Schoolbook',
#  'Castellar',
#  'Century Gothic',
#  'Samsung InterFace',
#  'Century',
#  'Bodoni MT',
#  'MS Outlook',
#  'Ink Free',
#  'HCR Batang ExtB',
#  'HoloLens MDL2 Assets',
#  'Arial',
#  'Baskerville Old Face',
#  'Gill Sans MT Ext Condensed Bold',
#  'Microsoft New Tai Lue',
#  'Lucida Sans',
#  'Segoe Print',
#  'Gulim',
#  'Bodoni MT',
#  'Imprint MT Shadow',
#  'Blackadder ITC',
#  'Tempus Sans ITC',
#  'Courier New',
#  'Elephant',
#  'Imprint MT Shadow',
#  'Arial',
#  'Gill Sans MT',
#  'Myanmar Text',
#  'Sitka Small',
#  'AralGothic',
#  'Wingdings 2',
#  'Lucida Sans',
#  'HYMyeongJo-Extra',
#  'Verdana',
#  'Georgia',
#  'Agency FB',
#  'Constantia',
#  'MingLiU-ExtB',
#  'NanumGothicOTF',
#  'Maiandra GD',
#  'HYPMokGak-Bold',
#  'Copperplate Gothic Bold',
#  'Yu Mincho',
#  'Segoe Script',
#  'Lucida Bright',
#  'Gadugi',
#  'Old English Text MT',
#  'Agency FB',
#  'MSugiHeulim',
#  'Palatino Linotype',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'HCR Dotum',
#  'Courier New',
#  'GyeonggiTitleV',
#  'Perpetua Titling MT',
#  'Arial',
#  'Lucida Fax',
#  'Viner Hand ITC',
#  'Chiller',
#  'TCometS',
#  'Snap ITC',
#  'Haettenschweiler',
#  'Onyx',
#  'GyeonggiTitle',
#  'NanumBarunGothic',
#  'Microsoft New Tai Lue',
#  'Bell MT',
#  'Courier New',
#  'MS Reference Specialty',
#  'UD Digi Kyokasho N-B',
#  'Colonna MT',
#  'MS Gothic',
#  'HyhwpEQ',
#  'Franklin Gothic Heavy',
#  'Harrington',
#  'MV Boli',
#  'Consolas',
#  'GyeonggiBatang',
#  'MS Reference Sans Serif',
#  'Perpetua',
#  'Wingdings 3',
#  'Marlett',
#  'HYGothic-Medium',
#  'Forte',
#  'Bell MT',
#  'Verdana',
#  'Batang',
#  'Corbel',
#  'Bodoni MT',
#  'Garamond',
#  'Brush Script MT',
#  'Pristina',
#  'Curlz MT',
#  'Yu Mincho',
#  'Nirmala UI',
#  'Modern No. 20',
#  'MV Boli',
#  'Bernard MT Condensed',
#  'Calisto MT',
#  'Onyx',
#  'Headline R',
#  'Viner Hand ITC',
#  'Trebuchet MS',
#  'Trebuchet MS',
#  'Constantia',
#  'Leelawadee UI',
#  'TComet',
#  'Batang',
#  'Lucida Sans',
#  'HYSinMyeongJo-Medium',
#  'Goudy Stout',
#  'Lucida Sans Typewriter',
#  'MBatang',
#  'Playbill',
#  'Arial',
#  'Century Gothic',
#  'Cooper Black',
#  'Gill Sans MT Condensed',
#  'Segoe MDL2 Assets',
#  'Candara',
#  'Comic Sans MS',
#  'Calibri',
#  'Perpetua',
#  'HCR Batang',
#  '?? ??? ?L',
#  'MGungJeong',
#  'Yu Gothic',
#  'Cambria',
#  'Californian FB',
#  'TwoCometS',
#  'Bookman Old Style',
#  'GyeonggiTitle',
#  'Verdana',
#  'Calibri',
#  '?? ??? ?R',
#  'Lucida Sans',
#  'Lucida Sans Unicode',
#  'Segoe UI Emoji',
#  'Microsoft YaHei',
#  'Arial',
#  'GyeonggiTitleV',
#  'Segoe UI',
#  'Arial Rounded MT Bold',
#  'Bodoni MT',
#  'Yu Mincho',
#  'Symbol',
#  'Calibri',
#  'Bookman Old Style',
#  'Segoe UI',
#  'Wide Latin',
#  'Lucida Bright',
#  'Bookman Old Style',
#  'Arial',
#  'Microsoft PhagsPa',
#  'Rockwell Condensed',
#  'HYPost-Light',
#  'Lucida Sans Typewriter',
#  'Ravie',
#  'HCR Batang',
#  'Sitka Small',
#  'Trebuchet MS',
#  'Headline R',
#  'Segoe Print',
#  'Yu Gothic',
#  'Candara',
#  'Verdana',
#  'Meiryo',
#  'NanumBarunGothic',
#  'Matura MT Script Capitals',
#  'HYGothic-Extra',
#  'TwoComet',
#  'Times New Roman',
#  'Mistral',
#  'Arial Rounded MT Bold',
#  'Segoe Print',
#  'HYGungSo-Bold',
#  'Mongolian Baiti',
#  'Tw Cen MT',
#  'Constantia',
#  'Felix Titling',
#  'High Tower Text',
#  'Microsoft PhagsPa',
#  'Cambria',
#  'Corbel',
#  'Wingdings',
#  'Harlow Solid Italic',
#  'Calisto MT',
#  'Century Schoolbook',
#  'HYHeadLine-Medium',
#  'Sitka Small',
#  'Myanmar Text',
#  'Franklin Gothic Book',
#  'Microsoft PhagsPa',
#  'Niagara Engraved',
#  'Magneto',
#  'Monotype Corsiva',
#  'Calibri',
#  'Bodoni MT',
#  'Gloucester MT Extra Condensed',
#  'Arial',
#  'Kristen ITC',
#  'Gill Sans Ultra Bold',
#  'Calisto MT',
#  'Palatino Linotype',
#  'HYSinMyeongJo-Medium',
#  'Eras Bold ITC',
#  'HYPost-Light',
#  'Garamond',
#  'Algerian',
#  'Microsoft JhengHei',
#  'Microsoft Sans Serif',
#  'Cambria',
#  'Lucida Bright',
#  'Microsoft New Tai Lue',
#  'Bodoni MT',
#  'Century Schoolbook',
#  'New Gulim',
#  'Segoe Script',
#  'Tw Cen MT',
#  'Bodoni MT',
#  'GyeonggiTitle',
#  'Palatino Linotype',
#  'Palace Script MT',
#  'Franklin Gothic Medium',
#  'Verdana',
#  'Meiryo',
#  'Times New Roman',
#  'Blackadder ITC',
#  'Segoe UI',
#  'Candara',
#  'Meiryo',
#  'Sylfaen',
#  'Footlight MT Light',
#  'Papyrus',
#  'Yu Mincho',
#  'NewJumja',
#  'Book Antiqua',
#  '?? ??? ?L',
#  'HCR Batang ExtB',
#  'Bodoni MT',
#  'Comic Sans MS',
#  'Bradley Hand ITC',
#  'Sitka Small',
#  'Bookman Old Style',
#  'Courier New',
#  'Elephant',
#  'Nirmala UI',
#  'Bahnschrift',
#  'Symbol',
#  'Goudy Stout',
#  'MoeumT R',
#  '?? ??? ?R',
#  'Magic R',
#  'Vivaldi',
#  'AralGothic',
#  'HYGungSo-Bold',
#  'Cambria',
#  'Gabriola',
#  'Jokerman',
#  'Bodoni MT',
#  'Franklin Gothic Book',
#  'HYGothic-Medium',
#  'Segoe UI',
#  'Segoe UI',
#  'HCR Batang ExtB',
#  'Wingdings',
#  'Lucida Bright',
#  'Rockwell',
#  'Gill Sans MT',
#  'Microsoft Sans Serif',
#  'Ebrima',
#  'HyhwpEQ',
#  'Copperplate Gothic Light',
#  'Centaur',
#  'Tw Cen MT Condensed',
#  'NanumBarunGothic',
#  'Papyrus',
#  'Times New Roman',
#  'Bodoni MT',
#  'Calibri',
#  'Book Antiqua',
#  'Ebrima',
#  'Eras Light ITC',
#  'NewJumja',
#  'Lucida Fax',
#  'Bodoni MT',
#  'Lucida Console',
#  'HYShortSamul-Medium',
#  'Lucida Fax',
#  'Microsoft YaHei',
#  'Segoe Script',
#  'Franklin Gothic Book',
#  '?? ??? ?R',
#  'Juice ITC',
#  'Bodoni MT',
#  'Gill Sans Ultra Bold Condensed',
#  'NanumBarunGothic',
#  'Tw Cen MT Condensed',
#  'Lucida Sans Typewriter',
#  '????',
#  'Bell MT',
#  'Sitka Small',
#  'Verdana',
#  'Century Gothic',
#  'Century Gothic',
#  'Gigi',
#  'Corbel',
#  'Microsoft YaHei',
#  'Segoe UI',
#  'Freestyle Script',
#  'Gill Sans MT',
#  'Nirmala UI',
#  'MGungHeulim',
#  'Bookshelf Symbol 7',
#  'Brush Script MT',
#  'Baskerville Old Face',
#  'TwoCometS',
#  'Century Gothic',
#  'Constantia',
#  'Consolas',
#  'MoeumT R',
#  'Tw Cen MT',
#  'MBatang',
#  'NanumGothicOTF',
#  'Franklin Gothic Demi Cond',
#  'HYGothic-Extra',
#  'Lucida Handwriting',
#  'Palatino Linotype',
#  'Yu Mincho',
#  'Yu Gothic',
#  'Palatino Linotype',
#  'Candara',
#  'Microsoft Himalaya',
#  'Malgun Gothic',
#  'Copperplate Gothic Bold',
#  'Calisto MT',
#  'Comic Sans MS',
#  'Script MT Bold',
#  'Stencil',
#  'Book Antiqua',
#  'Bauhaus 93',
#  'Consolas',
#  'Britannic Bold',
#  'Segoe UI',
#  '?? ??? ?L',
#  'Juice ITC',
#  'Rage Italic',
#  'Californian FB',
#  'Bookman Old Style',
#  'Tw Cen MT Condensed Extra Bold',
#  'Script MT Bold',
#  'Gill Sans Ultra Bold Condensed',
#  'Segoe UI',
#  'Times New Roman',
#  'Lucida Fax',
#  'Franklin Gothic Demi Cond',
#  'Trebuchet MS',
#  'Georgia',
#  'Sylfaen',
#  'MS Reference Sans Serif',
#  'Calisto MT',
#  'Arial',
#  'Bodoni MT',
#  'Berlin Sans FB Demi',
#  'Verdana',
#  'Gill Sans MT',
#  'Sitka Small',
#  'Trebuchet MS',
#  'Corbel',
#  'Malgun Gothic',
#  'SimSun',
#  'Georgia',
#  'Berlin Sans FB',
#  'Garamond',
#  'Mistral',
#  'Century',
#  'Candara',
#  'SimSun',
#  'Tahoma',
#  'MSugiJeong',
#  'Niagara Solid',
#  'Bookman Old Style',
#  'Gill Sans MT Condensed',
#  'Consolas',
#  'Lucida Sans Typewriter',
#  'Rockwell',
#  'Constantia',
#  'Segoe UI',
#  'Arial',
#  '????',
#  'Ami R',
#  'Perpetua Titling MT',
#  'Microsoft YaHei',
#  'Century Schoolbook',
#  'Candara',
#  'Bodoni MT',
#  'Cooper Black',
#  'Palace Script MT',
#  'Ebrima',
#  'Gill Sans Ultra Bold',
#  'Yet R',
#  'Arial',
#  'Microsoft Yi Baiti',
#  'Lucida Console',
#  'Calibri',
#  'OCR A Extended',
#  'Samsung InterFace',
#  '?? ??? ?B',
#  'Rockwell',
#  '?? ??? ?L',
#  'Comic Sans MS',
#  'Tahoma',
#  'Perpetua',
#  'Malgun Gothic',
#  'GyeonggiBatang',
#  'Informal Roman',
#  'Playbill',
#  'Tw Cen MT Condensed',
#  'Bookshelf Symbol 7',
#  'Courier New',
#  'Book Antiqua',
#  'Arial',
#  'Segoe UI',
#  'Corbel',
#  'Perpetua',
#  'Yu Gothic',
#  'Constantia',
#  'Yu Gothic',
#  'Century Gothic',
#  'Vladimir Script',
#  'Century Gothic',
#  'Book Antiqua',
#  'Perpetua Titling MT',
#  'Malgun Gothic',
#  'Rockwell Condensed',
#  'MGungHeulim',
#  'SimSun-ExtB',
#  'Sitka Small',
#  'Broadway',
#  'Segoe UI',
#  'Lucida Fax',
#  'HYPMokGak-Bold',
#  'Engravers MT',
#  'Lucida Sans Unicode',
#  'Segoe UI',
#  'Stencil',
#  'Bauhaus 93',
#  'Garamond',
#  'Gabriola',
#  'Californian FB',
#  'Segoe UI',
#  'Bodoni MT',
#  'Californian FB',
#  'Georgia',
#  'Gill Sans MT',
#  'Calibri',
#  'Rockwell Extra Bold',
#  'HYPost-Medium',
#  'Franklin Gothic Heavy',
#  'HCR Dotum Ext',
#  'Sitka Small',
#  'Microsoft PhagsPa',
#  'HoloLens MDL2 Assets',
#  'Lucida Fax',
#  'Georgia',
#  'Yu Gothic',
#  'UD Digi Kyokasho N-R',
#  'Book Antiqua',
#  'Agency FB',
#  'Tahoma',
#  'Leelawadee UI',
#  'Nirmala UI',
#  'Palatino Linotype',
#  'Palatino Linotype',
#  'Franklin Gothic Medium',
#  'Constantia',
#  'Broadway',
#  'Calisto MT',
#  'MJemokGothic',
#  'Berlin Sans FB',
#  'Magneto',
#  'Calisto MT',
#  'HCR Dotum',
#  'Eras Medium ITC',
#  'Microsoft Tai Le',
#  'Centaur',
#  'Calibri',
#  'Calibri',
#  'Franklin Gothic Book',
#  'Segoe UI',
#  'Ink Free',
#  'HCR Dotum',
#  'Franklin Gothic Demi',
#  'Bodoni MT',
#  'MS Mincho',
#  'Lucida Sans',
#  'Arial',
#  'Perpetua Titling MT',
#  'Book Antiqua',
#  '?? ??? ?R',
#  'Bell MT',
#  'Perpetua',
#  'Tw Cen MT',
#  'Tw Cen MT',
#  'Segoe UI',
#  'Malgun Gothic',
#  'Cambria',
#  '?? ??? ?B',
#  'Wingdings 2',
#  'Maiandra GD',
#  'Eras Demi ITC',
#  'Arial',
#  'Franklin Gothic Medium Cond',
#  'Comic Sans MS',
#  'Franklin Gothic Heavy',
#  'Lucida Sans Typewriter',
#  'Calibri',
#  'MHunmin',
#  'Arial',
#  'Microsoft JhengHei',
#  'Chiller',
#  'Wingdings 3',
#  'MJemokBatang',
#  'Trebuchet MS',
#  'Goudy Old Style',
#  'Calisto MT',
#  'MS Gothic',
#  'Yet R',
#  'Segoe UI Historic',
#  'HCR Batang',
#  'Berlin Sans FB',
#  'Elephant',
#  'Poor Richard',
#  'Franklin Gothic Demi',
#  'Lucida Handwriting',
#  'Gadugi',
#  'Perpetua',
#  'Arial',
#  'MDotum',
#  'HCR Batang Ext',
#  'Segoe UI',
#  'Pristina',
#  'Gadugi',
#  'Bradley Hand ITC',
#  'Lucida Bright',
#  'Curlz MT',
#  'Parchment',
#  'Ravie',
#  'Times New Roman',
#  'Edwardian Script ITC',
#  'Meiryo',
#  'Bodoni MT',
#  'HCR Batang Ext',
#  'Segoe UI',
#  'Lucida Fax',
#  '?? ??? ?B',
#  'Impact',
#  'Malgun Gothic',
#  'Lucida Sans Typewriter',
#  'Kunstler Script',
#  'Franklin Gothic Demi',
#  'Bodoni MT',
#  'HCR Dotum Ext',
#  'Goudy Old Style',
#  'Vivaldi',
#  'Segoe Script',
#  'Haettenschweiler',
#  'Californian FB',
#  'Segoe UI Symbol',
#  'Rockwell',
#  'French Script MT',
#  'Candara',
#  'Goudy Old Style',
#  'Lucida Sans Typewriter',
#  'Times New Roman',
#  'Mongolian Baiti',
#  'Lucida Sans Typewriter',
#  'Rockwell',
#  'Arial',
#  'Century Schoolbook',
#  'Niagara Engraved',
#  'Old English Text MT',
#  'Comic Sans MS',
#  'Niagara Solid',
#  'Javanese Text',
#  'MSugiJeong',
#  'GyeonggiBatang',
#  'Tempus Sans ITC',
#  'UD Digi Kyokasho N-B',
#  'GyeonggiBatang',
#  'HCR Batang ExtB',
#  'Segoe UI',
#  'MS Mincho',
#  'Poor Richard',
#  'New Gulim',
#  'Segoe Print',
#  'Agency FB',
#  'Times New Roman',
#  'Segoe UI',
#  'Harrington',
#  'Footlight MT Light',
#  'Berlin Sans FB']

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
